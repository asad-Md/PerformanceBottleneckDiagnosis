# %% [markdown]
# # ML Pipeline Foundation
#
# Runs the cleaned, leakage-safe data pipeline and writes the required artifacts.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
while ROOT.name != 'PerformanceBottleneckDiagnosis' and ROOT.parent != ROOT:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from ml.pipeline import run_pipeline

run_pipeline(
    input_csv=ROOT / 'src' / 'approach3' / 'perf_metrics.csv',
    artifact_dir=ROOT / 'src' / 'ml' / 'artifacts',
)
print('Pipeline artifacts generated.')
