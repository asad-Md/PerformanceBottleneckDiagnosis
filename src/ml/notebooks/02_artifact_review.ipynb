# %% [markdown]
# # Artifact Review
#
# Quick inspection notebook for generated cleaning, leakage, feature, and grouped CV artifacts.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd()
while ROOT.name != 'PerformanceBottleneckDiagnosis' and ROOT.parent != ROOT:
    ROOT = ROOT.parent
ART = ROOT / 'src' / 'ml' / 'artifacts'

print(json.dumps(json.loads((ART / 'cleaning_report.json').read_text()), indent=2))
display(pd.read_csv(ART / 'leakage_comparison.csv'))
display(pd.read_csv(ART / 'groupkfold_results.csv'))
print((ART / 'feature_cols.json').read_text())
