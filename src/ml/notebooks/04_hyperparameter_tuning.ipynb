# %% [markdown]
# # Phase 4 Hyperparameter Tuning
#
# Review artifacts generated by `ml.models.hyperparameter_tuning`.

# %%
from pathlib import Path
import json
import pandas as pd

artifact_dir = Path('../artifacts/phase4').resolve()
comparison = pd.read_csv(artifact_dir / 'hyperparameter_comparison.csv')
params = json.loads((artifact_dir / 'best_model_params.json').read_text())
display(comparison.sort_values('macro_f1', ascending=False))
params
