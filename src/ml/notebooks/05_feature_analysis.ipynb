# %% [markdown]
# # Phase 4 Feature Analysis
#
# Review feature importance and subset-selection artifacts.

# %%
from pathlib import Path
import pandas as pd

artifact_dir = Path('../artifacts/phase4').resolve()
feature_importance = pd.read_csv(artifact_dir / 'feature_importance.csv')
permutation = pd.read_csv(artifact_dir / 'permutation_importance.csv')
subsets = pd.read_csv(artifact_dir / 'feature_subset_comparison.csv')
display(feature_importance.head(20))
display(permutation.head(20))
display(subsets.sort_values('macro_f1', ascending=False))
