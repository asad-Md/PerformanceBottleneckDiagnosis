# %% [markdown]
# # Phase 4 Session Features
#
# Review grouped rolling, lag, and interaction feature experiment artifacts.

# %%
from pathlib import Path
import pandas as pd

artifact_dir = Path('../artifacts/phase4').resolve()
comparison = pd.read_csv(artifact_dir / 'session_feature_comparison.csv')
display(comparison.sort_values('macro_f1', ascending=False))
