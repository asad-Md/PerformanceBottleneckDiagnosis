# %% [markdown]
# # Phase 4 Ensembles
#
# Review ensemble and final recommendation artifacts.

# %%
from pathlib import Path
import pandas as pd

artifact_dir = Path('../artifacts/phase4').resolve()
ensembles = pd.read_csv(artifact_dir / 'ensemble_comparison.csv')
final = pd.read_csv(artifact_dir / 'final_model_comparison.csv')
display(ensembles.sort_values('macro_f1', ascending=False))
display(final.sort_values('macro_f1', ascending=False).head(10))
